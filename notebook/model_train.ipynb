# %%
import numpy as np
import pandas as pd
import ast

books = pd.read_csv('../dataset/Book_Details.csv')


print("Shape:", books.shape)
books.head(3)
# Out:
# Shape: (16225, 15)
#    Unnamed: 0  book_id                                    cover_image_uri  \
# 0           0        1  https://images-na.ssl-images-amazon.com/images...
# 1           1        2  https://images-na.ssl-images-amazon.com/images...
# 2           2        3  https://images-na.ssl-images-amazon.com/images...
#
#                                   book_title  \
# 0     Harry Potter and the Half-Blood Prince
# 1  Harry Potter and the Order of the Phoenix
# 2      Harry Potter and the Sorcerer's Stone
#
#                                         book_details  \
# 0  It is the middle of the summer, but there is a...
# 1  Harry Potter is about to start his fifth year ...
# 2  Harry Potter has no idea how famous he is. Tha...
#
#                      format                   publication_info  \
# 0  ['652 pages, Paperback']  ['First published July 16, 2005']
# 1  ['912 pages, Paperback']  ['First published June 21, 2003']
# 2  ['309 pages, Hardcover']  ['First published June 26, 1997']
#
#                                           authorlink        author num_pages  \
# 0  https://www.goodreads.com/author/show/1077326....  J.K. Rowling   ['652']
# 1  https://www.goodreads.com/author/show/1077326....  J.K. Rowling   ['912']
# 2  https://www.goodreads.com/author/show/1077326....  J.K. Rowling   ['309']
#
#                                               genres  num_ratings  \
# 0  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...      3292516
# 1  ['Young Adult', 'Fiction', 'Magic', 'Childrens...      3401709
# 2  ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...     10116247
#
#    num_reviews  average_rating  \
# 0        58398            4.58
# 1        64300            4.50
# 2       163493            4.47
#
#                                  rating_distribution
# 0  {'5': '2,244,154', '4': '775,028', '3': '219,8...
# 1  {'5': '2,178,760', '4': '856,178', '3': '293,2...
# 2  {'5': '6,544,542', '4': '2,348,390', '3': '856...

# %%
relevant_columns = [
    'book_title', 
    'book_details',     
    'author', 
    'genres', 
    'average_rating',
    'num_ratings',
    'publication_info',  
    'cover_image_uri'     
]

books = books[relevant_columns]

books.rename(columns={
    'book_title': 'title',
    'book_details': 'description',
    'cover_image_uri': 'image'
}, inplace=True)

books.dropna(inplace=True)
books.drop_duplicates(subset='title', inplace=True)

print("Data loaded successfully. Shape:", books.shape)
books.head(3)
# Out:
# Data loaded successfully. Shape: (15443, 8)
#                                        title  \
# 0     Harry Potter and the Half-Blood Prince
# 1  Harry Potter and the Order of the Phoenix
# 2      Harry Potter and the Sorcerer's Stone
#
#                                          description        author  \
# 0  It is the middle of the summer, but there is a...  J.K. Rowling
# 1  Harry Potter is about to start his fifth year ...  J.K. Rowling
# 2  Harry Potter has no idea how famous he is. Tha...  J.K. Rowling
#
#                                               genres  average_rating  \
# 0  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...            4.58
# 1  ['Young Adult', 'Fiction', 'Magic', 'Childrens...            4.50
# 2  ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...            4.47
#
#    num_ratings                   publication_info  \
# 0      3292516  ['First published July 16, 2005']
# 1      3401709  ['First published June 21, 2003']
# 2     10116247  ['First published June 26, 1997']
#
#                                                image
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...

# %%
import re  
import ast


def extract_year(text):
    text = str(text)
  
    match = re.search(r'\d{4}', text) 
    if match:
        return match.group(0) 
    else:
        return "Unknown" 

# Apply the fix
print("Fixing Year column...")
books['year'] = books['publication_info'].apply(extract_year)



def clean_genres(text):
   
    if pd.isna(text) or text == "":
        return ""
    
    text = str(text)
    
    try:
        
        genres_list = ast.literal_eval(text)
        
       
        if isinstance(genres_list, list):
            
            return " ".join(genres_list[:3])
        else:
            return str(text)
            
    except (ValueError, SyntaxError):
   
        clean_text = text.replace("[", "").replace("]", "").replace("'", "").replace(",", "")
        return clean_text


books['genres_clean'] = books['genres'].apply(clean_genres)
books['author_clean'] = books['author'].apply(lambda x: str(x).replace(" ", "") if not pd.isna(x) else "")
books['description_short'] = books['description'].apply(lambda x: " ".join(str(x).split()[:50]))
# Out:
# Fixing Year column...

# %%
books['tags'] = books['description_short'] + " " + books['genres_clean'] + " " + books['author_clean']

books['tags'] = books['tags'].apply(lambda x: x.lower())

final_df = books[['title', 'description', 'author', 'year', 'average_rating', 'image', 'tags', 'genres_clean']].copy()

print("Final Data Ready!")
final_df.head()
# Out:
# Final Data Ready!
#                                        title  \
# 0     Harry Potter and the Half-Blood Prince
# 1  Harry Potter and the Order of the Phoenix
# 2      Harry Potter and the Sorcerer's Stone
# 3   Harry Potter and the Prisoner of Azkaban
# 4        Harry Potter and the Goblet of Fire
#
#                                          description        author  year  \
# 0  It is the middle of the summer, but there is a...  J.K. Rowling  2005
# 1  Harry Potter is about to start his fifth year ...  J.K. Rowling  2003
# 2  Harry Potter has no idea how famous he is. Tha...  J.K. Rowling  1997
# 3  Harry Potter, along with his best friends, Ron...  J.K. Rowling  1999
# 4  It is the summer holidays and soon Harry Potte...  J.K. Rowling  2000
#
#    average_rating                                              image  \
# 0            4.58  https://images-na.ssl-images-amazon.com/images...
# 1            4.50  https://images-na.ssl-images-amazon.com/images...
# 2            4.47  https://images-na.ssl-images-amazon.com/images...
# 3            4.58  https://images-na.ssl-images-amazon.com/images...
# 4            4.57  https://images-na.ssl-images-amazon.com/images...
#
#                                                 tags  \
# 0  it is the middle of the summer, but there is a...
# 1  harry potter is about to start his fifth year ...
# 2  harry potter has no idea how famous he is. tha...
# 3  harry potter, along with his best friends, ron...
# 4  it is the summer holidays and soon harry potte...
#
#                   genres_clean
# 0  Fantasy Young Adult Fiction
# 1    Young Adult Fiction Magic
# 2  Fantasy Fiction Young Adult
# 3  Fantasy Fiction Young Adult
# 4  Fantasy Young Adult Fiction

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

cv = CountVectorizer(max_features=5000, stop_words='english')
vectors = cv.fit_transform(final_df['tags']).toarray()


similarity = cosine_similarity(vectors)

# %%
import pickle

pickle.dump(final_df, open('books.pkl', 'wb'))


pickle.dump(similarity, open('similarity.pkl', 'wb'))
